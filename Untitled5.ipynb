# %% [markdown]
# <a href="https://colab.research.google.com/github/SUAHJO/lab0---UserId/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-fd611dc8-de99-4909-8a24-1c5b7073267a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd611dc8-de99-4909-8a24-1c5b7073267a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020년01월.xls to 2020년01월.xls
# Saving 2020년02월.xls to 2020년02월.xls
# Saving 2020년03월.xls to 2020년03월.xls
# Saving 2020년04월.xls to 2020년04월.xls
# Saving 2020년05월.xls to 2020년05월.xls
# Saving 2020년06월.xls to 2020년06월.xls
# Saving 2020년07월.xls to 2020년07월.xls
# Saving 2020년08월.xls to 2020년08월.xls
# Saving 2020년09월.xls to 2020년09월.xls
# Saving 2020년10월.xls to 2020년10월.xls
# Saving 2020년11월.xls to 2020년11월.xls
# Saving 2020년12월.xls to 2020년12월.xls

# %%
data_1 = pd.read_excel(io.BytesIO(myfile['2020년01월.xls']))
data_2 = pd.read_excel(io.BytesIO(myfile['2020년02월.xls']))
data_3 = pd.read_excel(io.BytesIO(myfile['2020년03월.xls']))
data_4 = pd.read_excel(io.BytesIO(myfile['2020년04월.xls']))
data_5 = pd.read_excel(io.BytesIO(myfile['2020년05월.xls']))
data_6 = pd.read_excel(io.BytesIO(myfile['2020년06월.xls']))
data_7 = pd.read_excel(io.BytesIO(myfile['2020년07월.xls']))
data_8 = pd.read_excel(io.BytesIO(myfile['2020년08월.xls']))
data_9 = pd.read_excel(io.BytesIO(myfile['2020년09월.xls']))
data_10 = pd.read_excel(io.BytesIO(myfile['2020년10월.xls']))
data_11 = pd.read_excel(io.BytesIO(myfile['2020년11월.xls']))
data_12 = pd.read_excel(io.BytesIO(myfile['2020년12월.xls']))

# %%
data_1.head()
# Out:
#               날짜      시도 측정소명   측정소코드  아황산가스  일산화탄소     오존  이산화질소  PM10  PM2.5
# 0  2020-01-01 01  대전 대덕구  읍내동  525111  0.004    0.7  0.002  0.036  22.0    2.0
# 1  2020-01-01 02  대전 대덕구  읍내동  525111  0.004    0.7  0.005  0.033  17.0    7.0
# 2  2020-01-01 03  대전 대덕구  읍내동  525111  0.005    0.7  0.007  0.029  20.0   13.0
# 3  2020-01-01 04  대전 대덕구  읍내동  525111  0.005    0.6  0.015  0.017  20.0    9.0
# 4  2020-01-01 05  대전 대덕구  읍내동  525111  0.004    0.6  0.011  0.021  18.0    7.0

# %%
data_1['오염물질의 합'] = data_1['아황산가스'] + data_1['일산화탄소']+ data_1['오존']+ data_1['이산화질소']+ data_1['PM10']+ data_1['PM2.5']
print(data_1)
data_2['오염물질의 합'] = data_2['아황산가스'] + data_2['일산화탄소']+ data_2['오존']+ data_2['이산화질소']+ data_2['PM10']+ data_2['PM2.5']
print(data_1)
data_3['오염물질의 합'] = data_3['아황산가스'] + data_3['일산화탄소']+ data_3['오존']+ data_3['이산화질소']+ data_3['PM10']+ data_3['PM2.5']
print(data_1)
data_4['오염물질의 합'] = data_4['아황산가스'] + data_4['일산화탄소']+ data_4['오존']+ data_4['이산화질소']+ data_4['PM10']+ data_4['PM2.5']
print(data_1)
data_5['오염물질의 합'] = data_5['아황산가스'] + data_5['일산화탄소']+ data_5['오존']+ data_5['이산화질소']+ data_5['PM10']+ data_5['PM2.5']
print(data_1)
data_6['오염물질의 합'] = data_6['아황산가스'] + data_6['일산화탄소']+ data_6['오존']+ data_6['이산화질소']+ data_6['PM10']+ data_6['PM2.5']
print(data_1)
data_7['오염물질의 합'] = data_7['아황산가스'] + data_7['일산화탄소']+ data_7['오존']+ data_7['이산화질소']+ data_7['PM10']+ data_7['PM2.5']
print(data_1)
data_8['오염물질의 합'] = data_8['아황산가스'] + data_8['일산화탄소']+ data_8['오존']+ data_8['이산화질소']+ data_8['PM10']+ data_8['PM2.5']
print(data_1)
data_9['오염물질의 합'] = data_9['아황산가스'] + data_9['일산화탄소']+ data_9['오존']+ data_9['이산화질소']+ data_9['PM10']+ data_9['PM2.5']
print(data_1)
data_10['오염물질의 합'] = data_10['아황산가스'] + data_10['일산화탄소']+ data_10['오존']+ data_10['이산화질소']+ data_10['PM10']+ data_10['PM2.5']
print(data_1)
data_11['오염물질의 합'] = data_11['아황산가스'] + data_11['일산화탄소']+ data_11['오존']+ data_11['이산화질소']+ data_11['PM10']+ data_11['PM2.5']
print(data_1)
data_12['오염물질의 합'] = data_12['아황산가스'] + data_12['일산화탄소']+ data_12['오존']+ data_12['이산화질소']+ data_12['PM10']+ data_12['PM2.5']
print(data_1)
# Out:
#                  날짜      시도 측정소명   측정소코드  ...  이산화질소  PM10  PM2.5  오염물질의 합
# 0     2020-01-01 01  대전 대덕구  읍내동  525111  ...  0.036  22.0    2.0   24.742
# 1     2020-01-01 02  대전 대덕구  읍내동  525111  ...  0.033  17.0    7.0   24.742
# 2     2020-01-01 03  대전 대덕구  읍내동  525111  ...  0.029  20.0   13.0   33.741
# 3     2020-01-01 04  대전 대덕구  읍내동  525111  ...  0.017  20.0    9.0   29.637
# 4     2020-01-01 05  대전 대덕구  읍내동  525111  ...  0.021  18.0    7.0   25.636
# ...             ...     ...  ...     ...  ...    ...   ...    ...      ...
# 7435  2020-01-31 20   대전 서구  둔산동  525172  ...  0.022  46.0   30.0   76.443
# 7436  2020-01-31 21   대전 서구  둔산동  525172  ...  0.020  42.0   29.0   71.442
# 7437  2020-01-31 22   대전 서구  둔산동  525172  ...  0.020  39.0   30.0   69.441
# 7438  2020-01-31 23   대전 서구  둔산동  525172  ...  0.021  40.0   28.0   68.441
# 7439  2020-01-31 24   대전 서구  둔산동  525172  ...  0.017  38.0   29.0   67.440
#
# [7440 rows x 11 columns]
# ...

# %%
data_1[data_1['오염물질의 합']<= 50]
data_2[data_2['오염물질의 합']<= 50]
data_3[data_3['오염물질의 합']<= 50]
data_4[data_4['오염물질의 합']<= 50]
data_5[data_5['오염물질의 합']<= 50]
data_6[data_6['오염물질의 합']<= 50]
data_7[data_7['오염물질의 합']<= 50]
data_8[data_8['오염물질의 합']<= 50]
data_9[data_9['오염물질의 합']<= 50]
data_10[data_10['오염물질의 합']<= 50]
data_11[data_11['오염물질의 합']<= 50]
data_12[data_12['오염물질의 합']<= 50]
# Out:
#                  날짜      시도 측정소명   측정소코드  ...  이산화질소  PM10  PM2.5  오염물질의 합
# 1     2020-12-01 02  대전 대덕구  읍내동  525111  ...  0.034  33.0   12.0   45.837
# 15    2020-12-01 16  대전 대덕구  읍내동  525111  ...  0.024  37.0   12.0   49.351
# 16    2020-12-01 17  대전 대덕구  읍내동  525111  ...  0.029  32.0   15.0   47.350
# 37    2020-12-02 14  대전 대덕구  읍내동  525111  ...  0.021  30.0   11.0   41.550
# 38    2020-12-02 15  대전 대덕구  읍내동  525111  ...  0.021  21.0    9.0   30.451
# ...             ...     ...  ...     ...  ...    ...   ...    ...      ...
# 8176  2020-12-31 17   대전 서구  둔산동  525172  ...  0.020  37.0    6.0   43.440
# 8180  2020-12-31 21   대전 서구  둔산동  525172  ...  0.028  31.0   14.0   45.439
# 8181  2020-12-31 22   대전 서구  둔산동  525172  ...  0.032  29.0   16.0   45.540
# 8182  2020-12-31 23   대전 서구  둔산동  525172  ...  0.037  32.0   16.0   48.541
# 8183  2020-12-31 24   대전 서구  둔산동  525172  ...  0.038  29.0   16.0   45.542
#
# [3729 rows x 11 columns]

# %%
data_1[data_1['오염물질의 합'] > 50],data_1[data_1['오염물질의 합'] <= 100]
data_2[data_2['오염물질의 합'] > 50],data_2[data_2['오염물질의 합'] <= 100]
data_3[data_3['오염물질의 합'] > 50],data_3[data_3['오염물질의 합'] <= 100]
data_4[data_4['오염물질의 합'] > 50],data_4[data_4['오염물질의 합'] <= 100]
data_5[data_5['오염물질의 합'] > 50],data_5[data_5['오염물질의 합'] <= 100]
data_6[data_6['오염물질의 합'] > 50],data_6[data_6['오염물질의 합'] <= 100]
data_7[data_7['오염물질의 합'] > 50],data_7[data_7['오염물질의 합'] <= 100]
data_8[data_8['오염물질의 합'] > 50],data_8[data_8['오염물질의 합'] <= 100]
data_9[data_9['오염물질의 합'] > 50],data_9[data_9['오염물질의 합'] <= 100]
data_10[data_10['오염물질의 합'] > 50],data_10[data_10['오염물질의 합'] <= 100]
data_11[data_11['오염물질의 합'] > 50],data_11[data_11['오염물질의 합'] <= 100]
data_12[data_12['오염물질의 합'] > 50],data_12[data_12['오염물질의 합'] <= 100]
# Out:
# (                 날짜      시도 측정소명   측정소코드  ...  이산화질소  PM10  PM2.5  오염물질의 합
#  0     2020-12-01 01  대전 대덕구  읍내동  525111  ...  0.036  36.0   16.0   52.739
#  2     2020-12-01 03  대전 대덕구  읍내동  525111  ...  0.034  43.0   15.0   58.837
#  3     2020-12-01 04  대전 대덕구  읍내동  525111  ...  0.035  39.0   20.0   59.838
#  4     2020-12-01 05  대전 대덕구  읍내동  525111  ...  0.035  37.0   21.0   58.938
#  5     2020-12-01 06  대전 대덕구  읍내동  525111  ...  0.036  43.0   19.0   62.939
#  ...             ...     ...  ...     ...  ...    ...   ...    ...      ...
#  8171  2020-12-31 12   대전 서구  둔산동  525172  ...  0.017  37.0   16.0   53.340
#  8172  2020-12-31 13   대전 서구  둔산동  525172  ...  0.020  43.0   10.0   53.442
#  8177  2020-12-31 18   대전 서구  둔산동  525172  ...  0.022  54.0    5.0   59.440
#  8178  2020-12-31 19   대전 서구  둔산동  525172  ...  0.028  54.0   15.0   69.541
#  8179  2020-12-31 20   대전 서구  둔산동  525172  ...  0.026  38.0   17.0   55.439
#
#  [4206 rows x 11 columns],
# ...

# %%
data_1[data_1['오염물질의 합'] > 100],data_1[data_1['오염물질의 합'] <= 200]
data_2[data_2['오염물질의 합'] > 100],data_2[data_2['오염물질의 합'] <= 200]
data_3[data_3['오염물질의 합'] > 100],data_3[data_3['오염물질의 합'] <= 200]
data_4[data_4['오염물질의 합'] > 100],data_4[data_4['오염물질의 합'] <= 200]
data_5[data_5['오염물질의 합'] > 100],data_5[data_5['오염물질의 합'] <= 200]
data_6[data_6['오염물질의 합'] > 100],data_6[data_6['오염물질의 합'] <= 200]
data_7[data_7['오염물질의 합'] > 100],data_7[data_7['오염물질의 합'] <= 200]
data_8[data_8['오염물질의 합'] > 100],data_8[data_8['오염물질의 합'] <= 200]
data_9[data_9['오염물질의 합'] > 100],data_9[data_9['오염물질의 합'] <= 200]
data_10[data_10['오염물질의 합'] > 100],data_10[data_10['오염물질의 합'] <= 200]
data_11[data_11['오염물질의 합'] > 100],data_11[data_11['오염물질의 합'] <= 200]
data_12[data_12['오염물질의 합'] > 100],data_12[data_12['오염물질의 합'] <= 200]
# Out:
# (                 날짜      시도 측정소명   측정소코드  ...  이산화질소   PM10  PM2.5  오염물질의 합
#  8     2020-12-01 09  대전 대덕구  읍내동  525111  ...  0.045  112.0   39.0  151.951
#  9     2020-12-01 10  대전 대덕구  읍내동  525111  ...  0.044   84.0   35.0  119.750
#  10    2020-12-01 11  대전 대덕구  읍내동  525111  ...  0.036   65.0   38.0  103.647
#  18    2020-12-01 19  대전 대덕구  읍내동  525111  ...  0.047   71.0   30.0  101.754
#  19    2020-12-01 20  대전 대덕구  읍내동  525111  ...  0.044   81.0   24.0  105.748
#  ...             ...     ...  ...     ...  ...    ...    ...    ...      ...
#  8124  2020-12-29 13   대전 서구  둔산동  525172  ...  0.028   86.0   54.0  140.750
#  8125  2020-12-29 14   대전 서구  둔산동  525172  ...  0.031   73.0   44.0  117.749
#  8126  2020-12-29 15   대전 서구  둔산동  525172  ...  0.031   64.0   46.0  110.647
#  8127  2020-12-29 16   대전 서구  둔산동  525172  ...  0.037   67.0   44.0  111.652
#  8128  2020-12-29 17   대전 서구  둔산동  525172  ...  0.038   69.0   36.0  105.749
#
#  [811 rows x 11 columns],
# ...

# %%
data_1[data_1['오염물질의 합'] > 200]
data_2[data_2['오염물질의 합'] > 200]
data_3[data_3['오염물질의 합'] > 200]
data_4[data_4['오염물질의 합'] > 200]
data_5[data_5['오염물질의 합'] > 200]
data_6[data_6['오염물질의 합'] > 200]
data_7[data_7['오염물질의 합'] > 200]
data_8[data_8['오염물질의 합'] > 200]
data_9[data_9['오염물질의 합'] > 200]
data_10[data_10['오염물질의 합'] > 200]
data_11[data_11['오염물질의 합'] > 200]
data_12[data_12['오염물질의 합'] > 200]
# Out:
# Empty DataFrame
# Columns: [날짜, 시도, 측정소명, 측정소코드, 아황산가스, 일산화탄소, 오존, 이산화질소, PM10, PM2.5, 오염물질의 합]
# Index: []
