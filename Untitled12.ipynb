# %% [markdown]
# <a href="https://colab.research.google.com/github/SUAHJO/lab0---UserId/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df1 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년01월.xls')
df2 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년02월.xls')
df3 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년03월.xls')
df4 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년04월.xls')
df5 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년05월.xls')
df6 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년06월.xls')
df7 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년07월.xls')
df8 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년08월.xls')
df9 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년09월.xls')
df10 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년10월.xls')
df11 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년11월.xls')
df12 = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/dataset/2020년12월.xls')

# %%
df1['오염물질의 합'] = df1['아황산가스'] + df1['일산화탄소']+ df1['오존']+ df1['이산화질소']+ df1['PM10']+ df1['PM2.5']
df2['오염물질의 합'] = df2['아황산가스'] + df2['일산화탄소']+ df2['오존']+ df2['이산화질소']+ df2['PM10']+ df2['PM2.5']
df3['오염물질의 합'] = df3['아황산가스'] + df3['일산화탄소']+ df3['오존']+ df3['이산화질소']+ df3['PM10']+ df3['PM2.5']
df4['오염물질의 합'] = df4['아황산가스'] + df4['일산화탄소']+ df4['오존']+ df4['이산화질소']+ df4['PM10']+ df4['PM2.5']
df5['오염물질의 합'] = df5['아황산가스'] + df5['일산화탄소']+ df5['오존']+ df5['이산화질소']+ df5['PM10']+ df5['PM2.5']
df6['오염물질의 합'] = df6['아황산가스'] + df6['일산화탄소']+ df6['오존']+ df6['이산화질소']+ df6['PM10']+ df6['PM2.5']
df7['오염물질의 합'] = df7['아황산가스'] + df7['일산화탄소']+ df7['오존']+ df7['이산화질소']+ df7['PM10']+ df7['PM2.5']
df8['오염물질의 합'] = df8['아황산가스'] + df8['일산화탄소']+ df8['오존']+ df8['이산화질소']+ df8['PM10']+ df8['PM2.5']
df9['오염물질의 합'] = df9['아황산가스'] + df9['일산화탄소']+ df9['오존']+ df9['이산화질소']+ df9['PM10']+ df9['PM2.5']
df10['오염물질의 합'] = df10['아황산가스'] + df10['일산화탄소']+ df10['오존']+ df10['이산화질소']+ df10['PM10']+ df10['PM2.5']
df11['오염물질의 합'] = df11['아황산가스'] + df11['일산화탄소']+ df11['오존']+ df11['이산화질소']+ df11['PM10']+ df11['PM2.5']
df12['오염물질의 합'] = df12['아황산가스'] + df12['일산화탄소']+ df12['오존']+ df12['이산화질소']+ df12['PM10']+ df12['PM2.5']

# %%
df1.head()
# Out:
#               날짜      시도 측정소명   측정소코드  아황산가스  ...  이산화질소  PM10  PM2.5  오염물질의 합  품질수준
# 0  2020-01-01 01  대전 대덕구  읍내동  525111  0.004  ...  0.036  22.0    2.0   24.742  Blue
# 1  2020-01-01 02  대전 대덕구  읍내동  525111  0.004  ...  0.033  17.0    7.0   24.742  Blue
# 2  2020-01-01 03  대전 대덕구  읍내동  525111  0.005  ...  0.029  20.0   13.0   33.741  Blue
# 3  2020-01-01 04  대전 대덕구  읍내동  525111  0.005  ...  0.017  20.0    9.0   29.637  Blue
# 4  2020-01-01 05  대전 대덕구  읍내동  525111  0.004  ...  0.021  18.0    7.0   25.636  Blue
#
# [5 rows x 12 columns]

# %%
df1.plot.bar()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
grade_1 = [
         (df1['오염물질의 합'] <= 50),
         (df1['오염물질의 합'] > 50) & (df1['오염물질의 합'] <= 100),
         (df1['오염물질의 합'] > 100) & (df1['오염물질의 합'] <= 150),
         (df1['오염물질의 합'] > 150)
         ]
grade_2 = [
         (df2['오염물질의 합'] <= 50),
         (df2['오염물질의 합'] > 50) & (df2['오염물질의 합'] <= 100),
         (df2['오염물질의 합'] > 100) & (df2['오염물질의 합'] <= 150),
         (df2['오염물질의 합'] > 150)
         ]
grade_3 = [
         (df3['오염물질의 합'] <= 50),
         (df3['오염물질의 합'] > 50) & (df3['오염물질의 합'] <= 100),
         (df3['오염물질의 합'] > 100) & (df3['오염물질의 합'] <= 150),
         (df3['오염물질의 합'] > 150)
         ]
grade_4 = [
         (df4['오염물질의 합'] <= 50),
         (df4['오염물질의 합'] > 50) & (df4['오염물질의 합'] <= 100),
         (df4['오염물질의 합'] > 100) & (df4['오염물질의 합'] <= 150),
         (df4['오염물질의 합'] > 150)
         ]
grade_5 = [
         (df5['오염물질의 합'] <= 50),
         (df5['오염물질의 합'] > 50) & (df5['오염물질의 합'] <= 100),
         (df5['오염물질의 합'] > 100) & (df5['오염물질의 합'] <= 150),
         (df5['오염물질의 합'] > 150)
         ]
grade_6 = [
         (df6['오염물질의 합'] <= 50),
         (df6['오염물질의 합'] > 50) & (df6['오염물질의 합'] <= 100),
         (df6['오염물질의 합'] > 100) & (df6['오염물질의 합'] <= 150),
         (df6['오염물질의 합'] > 150)
         ]
grade_7 = [
         (df7['오염물질의 합'] <= 50),
         (df7['오염물질의 합'] > 50) & (df7['오염물질의 합'] <= 100),
         (df7['오염물질의 합'] > 100) & (df7['오염물질의 합'] <= 150),
         (df7['오염물질의 합'] > 150)
         ]
grade_8 = [
         (df8['오염물질의 합'] <= 50),
         (df8['오염물질의 합'] > 50) & (df8['오염물질의 합'] <= 100),
         (df8['오염물질의 합'] > 100) & (df8['오염물질의 합'] <= 150),
         (df8['오염물질의 합'] > 150)
         ]
grade_9 = [
         (df9['오염물질의 합'] <= 50),
         (df9['오염물질의 합'] > 50) & (df9['오염물질의 합'] <= 100),
         (df9['오염물질의 합'] > 100) & (df9['오염물질의 합'] <= 150),
         (df9['오염물질의 합'] > 150)
         ]
grade_10 = [
         (df10['오염물질의 합'] <= 50),
         (df10['오염물질의 합'] > 50) & (df10['오염물질의 합'] <= 100),
         (df10['오염물질의 합'] > 100) & (df10['오염물질의 합'] <= 150),
         (df10['오염물질의 합'] > 150)
         ]
grade_11 = [
         (df11['오염물질의 합'] <= 50),
         (df11['오염물질의 합'] > 50) & (df11['오염물질의 합'] <= 100),
         (df11['오염물질의 합'] > 100) & (df11['오염물질의 합'] <= 150),
         (df11['오염물질의 합'] > 150)
         ]
grade_12 = [
         (df12['오염물질의 합'] <= 50),
         (df12['오염물질의 합'] > 50) & (df12['오염물질의 합'] <= 100),
         (df12['오염물질의 합'] > 100) & (df12['오염물질의 합'] <= 150),
         (df12['오염물질의 합'] > 150)
         ]
gradelist = ['Blue', 'Green', 'Yellow', 'Red']
df1['품질수준'] = np.select(grade_1, gradelist, default='Not Specified')
df2['품질수준'] = np.select(grade_2, gradelist, default='Not Specified')
df3['품질수준'] = np.select(grade_3, gradelist, default='Not Specified')
df4['품질수준'] = np.select(grade_4, gradelist, default='Not Specified')
df5['품질수준'] = np.select(grade_5, gradelist, default='Not Specified')
df6['품질수준'] = np.select(grade_6, gradelist, default='Not Specified')
df7['품질수준'] = np.select(grade_7, gradelist, default='Not Specified')
df8['품질수준'] = np.select(grade_8, gradelist, default='Not Specified')
df9['품질수준'] = np.select(grade_9, gradelist, default='Not Specified')
df10['품질수준'] = np.select(grade_10, gradelist, default='Not Specified')
df11['품질수준'] = np.select(grade_11, gradelist, default='Not Specified')
df12['품질수준'] = np.select(grade_12, gradelist, default='Not Specified')

# %%
df_1b = df1.loc[df1['품질수준']=='Blue', ['오염물질의 합']]
df_1g = df1.loc[df1['품질수준']=='Green',['오염물질의 합']]
df_1y = df1.loc[df1['품질수준']=='Yellow',['오염물질의 합']]
df_1r = df1.loc[df1['품질수준']=='Red', ['오염물질의 합']]

# %%
df1.reset_index()
df2.reset_index()
df3.reset_index()
df4.reset_index()
df5.reset_index()
df6.reset_index()
df7.reset_index()
df8.reset_index()
df9.reset_index()
df10.reset_index()
df11.reset_index()
df12.reset_index()
# Out:
#       index             날짜      시도 측정소명  ...  PM10  PM2.5  오염물질의 합   품질수준
# 0         0  2020-12-01 01  대전 대덕구  읍내동  ...  36.0   16.0   52.739  Green
# 1         1  2020-12-01 02  대전 대덕구  읍내동  ...  33.0   12.0   45.837   Blue
# 2         2  2020-12-01 03  대전 대덕구  읍내동  ...  43.0   15.0   58.837  Green
# 3         3  2020-12-01 04  대전 대덕구  읍내동  ...  39.0   20.0   59.838  Green
# 4         4  2020-12-01 05  대전 대덕구  읍내동  ...  37.0   21.0   58.938  Green
# ...     ...            ...     ...  ...  ...   ...    ...      ...    ...
# 8179   8179  2020-12-31 20   대전 서구  둔산동  ...  38.0   17.0   55.439  Green
# 8180   8180  2020-12-31 21   대전 서구  둔산동  ...  31.0   14.0   45.439   Blue
# 8181   8181  2020-12-31 22   대전 서구  둔산동  ...  29.0   16.0   45.540   Blue
# 8182   8182  2020-12-31 23   대전 서구  둔산동  ...  32.0   16.0   48.541   Blue
# 8183   8183  2020-12-31 24   대전 서구  둔산동  ...  29.0   16.0   45.542   Blue
#
# [8184 rows x 13 columns]
